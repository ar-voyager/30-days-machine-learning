# %%
# importing pandas and numpy 
import pandas as pd
import numpy as np

# %%
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNzc5YWZhODU1OTMyYjZlNmRkOTljMTJiMGI5MjFhOSIsIm5iZiI6MTc1OTM1MDEyMi41ODA5OTk5LCJzdWIiOiI2OGRkOGQ2YTc3Y2U1ZTAwOGRiNDJhNTAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.b_a_5K1yDT3UuhdV1j4SM0QL109vLJ1NHJgcKanvQWg"
}

response = requests.get(url, headers=headers)

# %%
pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']].head()
# Out:
#         id                                           title  \
# 0   617126                    The Fantastic 4: First Steps
# 1  1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle
# 2   941109                                      Play Dirty
# 3  1267319                                          Mantis
# 4  1257009                                   Primitive War
#
#                                             overview release_date  popularity  \
# 0  Against the vibrant backdrop of a 1960s-inspir...   2025-07-22    393.9353
# 1  The Demon Slayer Corps are drawn into the Infi...   2025-07-18    382.7928
# 2  Expert thief Parker gets a shot at a major hei...   2025-09-30    402.6172
# 3  Mantis, an ace assassin, returns to the contra...   2025-09-26    365.4039
# 4  During the Vietnam War, a recon unit ventures ...   2025-08-21    368.2218
#
#    vote_average  vote_count
# 0         7.159        1790
# 1         7.795         418
# 2         6.349          86
# ...

# %%
df = pd.DataFrame()

# %%
for i in range(1, 5):

    url = f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page={i}"

    headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNzc5YWZhODU1OTMyYjZlNmRkOTljMTJiMGI5MjFhOSIsIm5iZiI6MTc1OTM1MDEyMi41ODA5OTk5LCJzdWIiOiI2OGRkOGQ2YTc3Y2U1ZTAwOGRiNDJhNTAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.b_a_5K1yDT3UuhdV1j4SM0QL109vLJ1NHJgcKanvQWg"
    }

    response = requests.get(url, headers=headers)

    print(response.text)
    temp_df = pd.DataFrame(response.json()["results"])[["id", "title", "overview", "release_date", "popularity", "vote_average", "vote_count"]]
    df = pd.concat([df, temp_df], axis=0, ignore_index=True)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/s94NjfKkcSczZ1FembwmQZwsuwY.jpg","genre_ids":[878,12],"id":617126,"original_language":"en","original_title":"The Fantastic 4: First Steps","overview":"Against the vibrant backdrop of a 1960s-inspired, retro-futuristic world, Marvel's First Family is forced to balance their roles as heroes with the strength of their family bond, while defending Earth from a ravenous space god called Galactus and his enigmatic Herald, Silver Surfer.","popularity":393.9353,"poster_path":"/cm8TNGBGG0aBfWj0LgrESHv8tir.jpg","release_date":"2025-07-22","title":"The Fantastic 4: First Steps","video":false,"vote_average":7.159,"vote_count":1790},{"adult":false,"backdrop_path":"/1RgPyOhN4DRs225BGTlHJqCudII.jpg","genre_ids":[16,28,14,53],"id":1311031,"original_language":"ja","original_title":"劇場版「鬼滅の刃」無限城編 第一章 猗窩座再来","overview":"The Demon Slayer Corps are drawn into the Infinity Castle, where Tanjiro, Nezuko, and the Hashira face terrifying Upper Rank demons
# ...
