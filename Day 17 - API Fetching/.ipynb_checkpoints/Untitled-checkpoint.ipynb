# %%
# import pandas
import pandas as pd
# import numpy
import numpy

# %%
# import requests
import requests

url = "https://youtube138.p.rapidapi.com/channel/videos/"

payload = {
	"id": "UCJ5v_MCY6GNUBTO8-D3XoAg",
	"filter": "videos_latest",
	"cursor": "",
	"hl": "en",
	"gl": "US"
}
headers = {
	"x-rapidapi-key": "fb634bafdcmsh30df3bd944e5015p182342jsn8129c9f0c86d",
	"x-rapidapi-host": "youtube138.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

data= response.json()

# %%
# video upload list data
rows = []

# looping
for item in range(len(data['contents'])):
     if data['contents'][item].get('type') == 'video':
         rows.append({
                'type': data['contents'][item]['type'],
                'video_id': data['contents'][item]['video'].get('videoId'),
                'title': data['contents'][item]['video'].get('title', 'NaN'),
                'length_seconds': data['contents'][item]['video'].get('lengthSeconds', 'NaN'),
                'published_time': data['contents'][item]['video'].get('publishedTimeText', 'NaN'),
                'views': data['contents'][item]['video'].get('stats', 'NaN'),
                'is_live': data['contents'][item]['video'].get('isLiveNow', 'NaN'),
                'thumbnail_url': data['contents'][item]['video'].get('thumbnails', 'NaN'),  # highest resolution
                'moving_thumbnail_url': data['contents'][item]['video'].get('movingThumbnails', 'NaN')[-1]
        })

pd.DataFrame(rows)
# Out:
#      type     video_id                                              title  \
# 0   video  mt_BKSNe4gM  FULL MATCH: Motor City Machine Guns vs. Los Am...
# 1   video  uoTHzyQe5B8            Full SmackDown highlights: Feb. 6, 2026
# 2   video  hT3PSURpwCg  FULL MATCH: Randy Orton qualifies for the Elim...
# 3   video  qhl0XrmdhnI  Trick Williams steps up to Drew McIntyre: Smac...
# 4   video  BgLrVSS9-vE  Jade Cargill & Jordynne Grace vs. Liv Morgan &...
# 5   video  N-dfyxKmd50    SmackDown to air on Syfy on Feb. 13 and Feb. 20
# 6   video  WVAR0ZEyQgg  Jade Cargill and Jordynne Grace confront Liv M...
# 7   video  N0GX38QXZZ0  Candice LeRae seeks help for Johnny Gargano’s ...
# 8   video  _GusEqba5hY  Tama Tonga beats Shinsuke Nakamura thanks to T...
# 9   video  rGMmbQTuR1I  Jacob Fatu unleashes a second attack on Drew M...
# 10  video  Osld3PDg2hQ  Oba Femi destroys Kit Wilson in impromptu show...
# 11  video  FBX9pqxjJoo  Tiffany Stratton qualifies for the Elimination...
# 12  video  vSerP5YhWnM  Carmelo Hayes defeats The Miz: SmackDown highl...
# 13  video  Ly57uuZPFUM  Rhea Ripley & IYO SKY vs. Giulia and Kiana Jam...
# 14  video  Jk7juVV0C3I  Cody Rhodes: “Drew McIntyre won't make it to W...
# 15  video  mF4_-wWwsuA  Cody Rhodes ATTACKS Drew McIntyre: SmackDown h...
# 16  video  XR_zYymfgGY  Liv Morgan heads to SmackDown after winning Ro...
# 17  video  0ncsstUYqTY  Roman Reigns before Royal Rumble win: “They be...
# 18  video  QOEoP9THxok  FULL MATCH: Becky Lynch vs. Bayley | Steel Cag...
# 19  video  ksFZBPkGBoA       Roman Reigns’ most iconic wins: WWE Playlist
# 20  video  EMtBRA-fPbA  Jackson Drake defends the Evolve Title against...
# 21  video  VsS02tHOP7U  FULL INTERVIEW: Je’Von Evans wants to be the y...
# 22  video  7n7DKisJo3o  10 brutal moments from Stephanie Vaquer vs. Ra...
# 23  video  Angp_PrNPRk  FULL MATCH: LA Knight vs. Drew McIntyre vs. Ji...
# 24  video  vlyxk__RFYY  Every appearance of the “masked man”: WWE Play...
# 25  video  96j8xcyCUQk   Top 10 WWE NXT moments: WWE Top 10, Feb. 3, 2026
# 26  video  oKRl_vhSvx8  FULL MATCH: Men's Elimination Chamber Match: E...
# 27  video  pMUgwN5Puqc                  Full NXT highlights: Feb. 3, 2026
#
#     length_seconds published_time              views  is_live  \
# 0              561    9 hours ago   {'views': 37913}    False
# 1              694   21 hours ago  {'views': 754038}    False
# 2             1014   21 hours ago  {'views': 789643}    False
# 3              176   22 hours ago  {'views': 312925}    False
# 4              192   22 hours ago  {'views': 358135}    False
# 5               20   22 hours ago   {'views': 36732}    False
# 6              168   23 hours ago  {'views': 437989}    False
# 7               93   23 hours ago  {'views': 189736}    False
# 8              192   23 hours ago  {'views': 133834}    False
# 9              164   23 hours ago  {'views': 412718}    False
# 10             190   23 hours ago  {'views': 403209}    False
# 11             199   23 hours ago  {'views': 218663}    False
# 12             190      1 day ago  {'views': 107894}    False
# 13             194      1 day ago  {'views': 214838}    False
# 14             209      1 day ago  {'views': 283901}    False
# 15             131      1 day ago  {'views': 360957}    False
# 16             172      1 day ago   {'views': 57980}    False
# 17             276      1 day ago  {'views': 314960}    False
# 18             912      1 day ago   {'views': 35280}    False
# 19            2640      1 day ago  {'views': 308742}    False
# 20             173     2 days ago   {'views': 24582}    False
# 21             822     2 days ago   {'views': 11914}    False
# 22             497     2 days ago  {'views': 107254}    False
# 23            1197     2 days ago  {'views': 120940}    False
# 24             309     2 days ago  {'views': 349869}    False
# 25             531     3 days ago   {'views': 90935}    False
# 26            3104     3 days ago  {'views': 605080}    False
# 27             548     3 days ago  {'views': 180719}    False
#
#                                         thumbnail_url  \
# 0   [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 1   [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 2   [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 3   [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 4   [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 5   [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 6   [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 7   [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 8   [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 9   [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 10  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 11  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 12  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 13  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 14  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 15  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 16  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 17  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 18  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 19  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 20  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 21  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 22  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 23  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 24  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 25  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 26  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 27  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
#
#                                  moving_thumbnail_url
# 0   [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 1   [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 2   [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 3   [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 4   [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 5   [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 6   [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 7   [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 8   [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 9   [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 10  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 11  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 12  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 13  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 14  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 15  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 16  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 17  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 18  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 19  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 20  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 21  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 22  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 23  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 24  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 25  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 26  [{'height': 180, 'url': 'https://i.ytimg.com/a...
# 27  [{'height': 180, 'url': 'https://i.ytimg.com/a...
