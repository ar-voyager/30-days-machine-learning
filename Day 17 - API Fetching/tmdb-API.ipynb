# %%
# import pandas
import pandas as pd
# import numpy
import numpy as np

# %%
# import requests
import requests

url = "https://api.themoviedb.org/3/movie/top_rated"
headers = {
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwNWM3NWY1MjNkYzYyZmFiNzVhNjJmYTc1MGM1NWEzMSIsIm5iZiI6MTc3MDM5MzIzMy42Mywic3ViIjoiNjk4NjBlOTFmMmU5NzU0YWI0NDhkZTJiIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.xze-JgRv5x5MhGWkMknwVIKVy_0vBD1-byIpdfI5f2I"
}

response = requests.get(url, headers=headers)
# Get Data
data = response.json()

# %%
# Let Convert it into the DataFrame()
movies = data['results']
# DataGFrame
pd.DataFrame(movies)
# Out:
#     adult                     backdrop_path                    genre_ids  \
# 0   False   /c4sKPgyJj19GBCAvUjpPRiiA45.jpg                     [35, 53]
# 1   False  /mT26Lktm0paarsL2Au2VlOLJICh.jpg                     [27, 35]
# 2   False  /264UPQQm6cIF3NwXQDrj8W6e7K8.jpg          [12, 10751, 35, 14]
# 3   False  /xdH8k2O6mpLv4szeLkQGiM1aSOC.jpg  [12, 10751, 10770, 878, 14]
# 4   False  /aVgqxRQ8M8aJnfO1eUZEmNJSTxm.jpg                 [28, 12, 35]
# 5   False  /nr5smF4avc77lhWHNcGLF7guXv1.jpg                   [27, 9648]
# 6   False  /iV8jui6eHwaj93NJqGPd8O3UuHf.jpg              [35, 18, 10749]
# 7   False  /oEH2tn8G1YGEhNBVqSAW6k1C9iB.jpg                         [35]
# 8   False  /o2iN9n2ShVqobqnYR0odM6yIlgW.jpg                     [53, 27]
# 9   False  /mYsUWQoOYme8T6OELieOuHM08PH.jpg                     [27, 53]
# 10  False  /ohqTNoA6pYzTXookp8UXNWQlAgY.jpg                         [35]
# 11  False  /zKZqtGKmysHNbmsJQWS51rywROw.jpg            [18, 53, 28, 878]
# ...

# %%
# Get more Movies Data through Pagination
# First import time module
import time

session = requests.Session()
session.headers.update(headers)

all_movies = []

for page in range(1, 534): 
    params = {
        "page": 1
    }
    # first 5 pages
    try:
        params["page"] = page
        response = session.get(url, headers=headers, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()
        all_movies.extend(data["results"])

        print(f"Fetched page {page}")
        time.sleep(0.5)   # Sleep for 0.5
    except requests.exceptions.RequestException as e:
        print(f"Error on page {page}: {e}")
        break

print("Total movies fetched:", len(all_movies))
# Out:
# Fetched page 1
# Fetched page 2
# Fetched page 3
# Fetched page 4
# Fetched page 5
# Fetched page 6
# Fetched page 7
# Fetched page 8
# Fetched page 9
# Fetched page 10
# Fetched page 11
# Fetched page 12
# Fetched page 13
# Fetched page 14
# Fetched page 15
# Fetched page 16
# Fetched page 17
# Fetched page 18
# Fetched page 19
# Fetched page 20
# Fetched page 21
# Fetched page 22
# Fetched page 23
# Fetched page 24
# Fetched page 25
# Fetched page 26
# Fetched page 27
# Fetched page 28
# Fetched page 29
# Fetched page 30
# Fetched page 31
# Fetched page 32
# Fetched page 33
# Fetched page 34
# Fetched page 35
# Fetched page 36
# Fetched page 37
# Fetched page 38
# Fetched page 39
# Fetched page 40
# Fetched page 41
# Fetched page 42
# Fetched page 43
# Fetched page 44
# Fetched page 45
# Fetched page 46
# Fetched page 47
# Fetched page 48
# Fetched page 49
# Fetched page 50
# Fetched page 51
# Fetched page 52
# Fetched page 53
# Fetched page 54
# Fetched page 55
# Fetched page 56
# ...

# %%
movies = pd.DataFrame(all_movies)
movies.to_csv('movies_data.csv', index=False)

# %%
# read_csv() file
df = pd.read_csv('movies_data.csv')
df
# Out:
#       adult                     backdrop_path             genre_ids      id  \
# 0     False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg              [18, 80]     278
# 1     False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg              [18, 80]     238
# 2     False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg              [18, 80]     240
# 3     False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg       [18, 36, 10752]     424
# 4     False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg                  [18]     389
# ...     ...                               ...                   ...     ...
# 9995  False  /lj7enxOyRXazcCIFJyCn9dLuF2V.jpg        [35, 80, 9648]  338964
# 9996  False  /aMUBgI9LyeX4QJ5Y1cizPFPpAYD.jpg          [35, 80, 18]   16991
# 9997  False   /AF0PiDItegyUtlBGDMGlSQbtro.jpg              [35, 27]   43593
# 9998  False  /6epafgrlSnOJrNakHgY7pbYr513.jpg                  [35]   19794
# 9999  False  /gIhLlTYILo2BP6xt2KeBNxQDN4E.jpg  [12, 35, 10751, 878]   11425
#
#      original_language              original_title  \
# ...

# %%
# fancy indexing
# boolean indexing
df[df['backdrop_path'].isna()].shape
# Out:
# (13, 14)

# %%
# import new upcoming movies data

import requests

new_url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwNWM3NWY1MjNkYzYyZmFiNzVhNjJmYTc1MGM1NWEzMSIsIm5iZiI6MTc3MDM5MzIzMy42Mywic3ViIjoiNjk4NjBlOTFmMmU5NzU0YWI0NDhkZTJiIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.xze-JgRv5x5MhGWkMknwVIKVy_0vBD1-byIpdfI5f2I"
}

response = requests.get(new_url, headers=headers)

data = response.json()

# %%
# Let it convert into the DataFrame
new_movies = data['results']
pd.DataFrame(new_movies).head(1)
# Out:
#    adult                     backdrop_path      genre_ids      id  \
# 0  False  /tyjXlexbNZQ0ZT1KEJslQtBirqc.jpg  [12, 53, 878]  840464
#
#   original_language          original_title  \
# 0                en  Greenland 2: Migration
#
#                                             overview  popularity  \
# 0  Having found the safety of the Greenland bunke...    515.6229
#
#                         poster_path release_date                   title  \
# 0  /z2tqCJLsw6uEJ8nJV8BsQXGa3dr.jpg   2026-01-07  Greenland 2: Migration
#
#    video  vote_average  vote_count
# 0  False         6.528         338

# %%
# Get more Movies Data through Pagination
# importing time module
import time
session = requests.Session()
session.headers.update(headers)

all_movies = []

for page in range(1, 534): 
    params = {
        "page": 1
    }
    # try 
    try:
        params["page"] = page
        response = session.get(new_url, headers=headers, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()
        all_movies.extend(data["results"])

        print(f"Fetched page {page}")
        time.sleep(0.5)   # Sleep for 0.5
    # except
    except requests.exceptions.RequestException as e:
        print(f"Error on page {page}: {e}")
        break

print("Total movies fetched:", len(all_movies))
# Out:
# Fetched page 1
# Fetched page 2
# Fetched page 3
# Fetched page 4
# Fetched page 5
# Fetched page 6
# Fetched page 7
# Fetched page 8
# Fetched page 9
# Fetched page 10
# Fetched page 11
# Fetched page 12
# Fetched page 13
# Fetched page 14
# Fetched page 15
# Fetched page 16
# Fetched page 17
# Fetched page 18
# Fetched page 19
# Fetched page 20
# Fetched page 21
# Fetched page 22
# Fetched page 23
# Fetched page 24
# Fetched page 25
# Fetched page 26
# Fetched page 27
# Fetched page 28
# Fetched page 29
# Fetched page 30
# Fetched page 31
# Fetched page 32
# Fetched page 33
# Fetched page 34
# Fetched page 35
# Fetched page 36
# Fetched page 37
# Fetched page 38
# Fetched page 39
# Fetched page 40
# Fetched page 41
# Fetched page 42
# Fetched page 43
# Fetched page 44
# Fetched page 45
# Fetched page 46
# Fetched page 47
# Fetched page 48
# Fetched page 49
# Fetched page 50
# Fetched page 51
# Fetched page 52
# Fetched page 53
# Fetched page 54
# Fetched page 55
# Fetched page 56
# ...

# %%
new_movies = pd.DataFrame(all_movies)
new_movies.to_csv('new_movies.csv', index=False)

# %%
pd.read_csv('new_movies.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              1022 non-null   bool
#  1   backdrop_path      595 non-null    object
#  2   genre_ids          1022 non-null   object
#  3   id                 1022 non-null   int64
#  4   original_language  1022 non-null   object
#  5   original_title     1022 non-null   object
#  6   overview           917 non-null    object
#  7   popularity         1022 non-null   float64
#  8   poster_path        865 non-null    object
#  9   release_date       1021 non-null   object
#  10  title              1022 non-null   object
#  11  video              1022 non-null   bool
#  12  vote_average       1022 non-null   float64
#  13  vote_count         1022 non-null   int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 97.9+ KB

# %%
pd.read_csv('movies_data.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              10000 non-null  bool
#  1   backdrop_path      9987 non-null   object
#  2   genre_ids          10000 non-null  object
#  3   id                 10000 non-null  int64
#  4   original_language  10000 non-null  object
#  5   original_title     10000 non-null  object
#  6   overview           9998 non-null   object
#  7   popularity         10000 non-null  float64
#  8   poster_path        9993 non-null   object
#  9   release_date       9997 non-null   object
#  10  title              10000 non-null  object
#  11  video              10000 non-null  bool
#  12  vote_average       10000 non-null  float64
#  13  vote_count         10000 non-null  int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 957.2+ KB
