# %%
# import libraries
import numpy as np
import pandas as pd 
from sklearn.datasets import make_classification

# %%
X, y = make_classification(
    n_features=5,
    n_redundant=0,
    n_informative=5,
    n_clusters_per_class=1
)

# %%
df = pd.DataFrame(X, columns=['col1','col2','col3','col4','col5'])
df['target'] = y 
print(df.shape)

# top rows
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  0.281820  1.160955 -1.546861  1.034891  0.096428       1
# 1  0.933603 -0.182939  0.023930  3.062630  0.149346       0
# 2 -2.251385  1.487364 -2.106552 -1.876822 -1.867455       0
# 3 -0.314837 -0.376796 -1.142931  0.002112 -1.338753       0
# 4 -0.797347  1.127981 -2.956264 -0.723843 -1.950815       0

# %% [markdown]
# ## *Sampling Functions*

# %%
# Function for row sampling
def sample_rows(df, percent): # parameters
    return df.sample(frac=percent, replace=True)

# %%
# Function for combined sampling

# import random
import random
def sample_features(df, percent): # Formal Arguments
    cols = random.sample(df.columns.tolist()[:-1], int(percent*df.shape[1]))
    new_df = df[cols]
    new_df['target'] = df['target']
    return new_df

# %%
# Function for combined sampling
def combined_sampling(df, row_percent, col_percent):
    new_df = sample_rows(df, row_percent)
    return sample_features(new_df, col_percent)

# %%
# Row Sampling
df1 = sample_rows(df, 0.2) # Actual Arguments

# %%
df2 = sample_rows(df, 0.2) # Actual Arguments

# %%
df3 = sample_rows(df, 0.2) # Actual Arguments:

# %%
df1.shape, df2.shape, df3.shape
# Out:
# ((20, 6), (20, 6), (20, 6))

# %%
# import decision tree classifier
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
# Train the model
clf1.fit(df1.iloc[:,0:5], df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5], df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5], df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
# plot tree 
from sklearn.tree import plot_tree
plot_tree(clf1)
# Out:
# [Text(0.2857142857142857, 0.9, 'x[0] <= -1.09\ngini = 0.5\nsamples = 20\nvalue = [10, 10]'),
#  Text(0.14285714285714285, 0.7, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.21428571428571427, 0.8, 'True  '),
#  Text(0.42857142857142855, 0.7, 'x[4] <= -1.526\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.3571428571428571, 0.8, '  False'),
#  Text(0.2857142857142857, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5714285714285714, 0.5, 'x[4] <= -1.199\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.42857142857142855, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7142857142857143, 0.3, 'x[2] <= 0.576\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5714285714285714, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8571428571428571, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.5, 0.75, 'x[0] <= -0.329\ngini = 0.48\nsamples = 20\nvalue = [12, 8]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.4, 0.9166666666666666, 'x[0] <= -1.375\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.2, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.30000000000000004, 0.8333333333333333, 'True  '),
#  Text(0.6, 0.75, 'x[2] <= -0.046\ngini = 0.375\nsamples = 16\nvalue = [4, 12]'),
#  Text(0.5, 0.8333333333333333, '  False'),
#  Text(0.4, 0.5833333333333334, 'x[3] <= -1.647\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.2, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.4166666666666667, 'x[3] <= -0.123\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.4, 0.25, 'x[3] <= -0.271\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2, 0.08333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.25, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.8, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
clf1.predict(np.array([0.551380, -1.876815, -1.807618, -1.557932, -0.039809]).reshape(1,5))
# Out:
# C:\Users\ratha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([0.551380, -1.876815, -1.807618, -1.557932, -0.039809]).reshape(1,5))
# Out:
# C:\Users\ratha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([0.551380, -1.876815, -1.807618, -1.557932, -0.039809]).reshape(1,5))
# Out:
# C:\Users\ratha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# sample_features
df1 = sample_features(df, 0.80)
# Out:
# C:\Users\ratha\AppData\Local\Temp\ipykernel_2036\3555926235.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df2 = sample_features(df, 0.80)
# Out:
# C:\Users\ratha\AppData\Local\Temp\ipykernel_2036\3555926235.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df3 = sample_features(df, 0.80)
# Out:
# C:\Users\ratha\AppData\Local\Temp\ipykernel_2036\3555926235.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df1.shape, df2.shape, df3.shape
# Out:
# ((100, 5), (100, 5), (100, 5))

# %%
# import decision tree classifier
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
# Train the model
clf1.fit(df1.iloc[:,0:4], df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:4], df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:4], df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col5', 'col1', 'col4', 'col3', 'target'], dtype='object')
# Index(['col5', 'col2', 'col3', 'col4', 'target'], dtype='object')
# Index(['col5', 'col3', 'col2', 'col4', 'target'], dtype='object')

# %%
# Import tree
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.5098039215686274, 0.95, 'x[1] <= -0.023\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.17647058823529413, 0.85, 'x[0] <= -3.028\ngini = 0.34\nsamples = 46\nvalue = [36, 10]'),
#  Text(0.3431372549019608, 0.8999999999999999, 'True  '),
#  Text(0.13725490196078433, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21568627450980393, 0.75, 'x[1] <= -1.095\ngini = 0.32\nsamples = 45\nvalue = [36, 9]'),
#  Text(0.0784313725490196, 0.65, 'x[3] <= -3.626\ngini = 0.185\nsamples = 29\nvalue = [26, 3]'),
#  Text(0.0392156862745098, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11764705882352941, 0.55, 'x[3] <= -0.691\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.0784313725490196, 0.45, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.1568627450980392, 0.45, 'x[3] <= -0.576\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.11764705882352941, 0.35, 'x[0] <= -0.986\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.2640845070422535, 0.9615384615384616, 'x[1] <= -0.396\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.20774647887323944, 0.8846153846153846, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.23591549295774647, 0.9230769230769231, 'True  '),
#  Text(0.3204225352112676, 0.8846153846153846, 'x[2] <= -1.754\ngini = 0.496\nsamples = 92\nvalue = [50, 42]'),
#  Text(0.29225352112676056, 0.9230769230769231, '  False'),
#  Text(0.11267605633802817, 0.8076923076923077, 'x[0] <= -0.897\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.056338028169014086, 0.7307692307692307, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.16901408450704225, 0.7307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.528169014084507, 0.8076923076923077, 'x[0] <= -1.541\ngini = 0.498\nsamples = 77\nvalue = [36, 41]'),
#  Text(0.28169014084507044, 0.7307692307692307, 'x[2] <= 1.256\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.2642857142857143, 0.9583333333333334, 'x[2] <= -0.396\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.20714285714285716, 0.875, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.2357142857142857, 0.9166666666666667, 'True  '),
#  Text(0.32142857142857145, 0.875, 'x[1] <= -1.754\ngini = 0.496\nsamples = 92\nvalue = [50, 42]'),
#  Text(0.29285714285714287, 0.9166666666666667, '  False'),
#  Text(0.11428571428571428, 0.7916666666666666, 'x[0] <= -0.897\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.05714285714285714, 0.7083333333333334, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.17142857142857143, 0.7083333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5285714285714286, 0.7916666666666666, 'x[0] <= -1.541\ngini = 0.498\nsamples = 77\nvalue = [36, 41]'),
#  Text(0.2857142857142857, 0.7083333333333334, 'x[1] <= 1.256\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
# ...

# %%
# predict the model
clf1.predict(np.array([0.096428, 0.281820, 1.034891, -1.546861]).reshape(1,4))
# Out:
# C:\Users\ratha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([0.096428, 0.281820, 1.034891, -1.546861]).reshape(1,4))
# Out:
# C:\Users\ratha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([0.096428, 0.281820, 1.034891, -1.546861]).reshape(1,4))
# Out:
# C:\Users\ratha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# combined_sampling
combined_sampling(df, 0.10, 0.49)
# Out:
# C:\Users\ratha\AppData\Local\Temp\ipykernel_2036\3555926235.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']
#         col1      col4  target
# 17  0.924199  0.011065       0
# 88  0.174052 -1.461108       0
# 64 -0.615370  1.599598       1
# 16 -1.930879  0.158766       1
# 48  0.721604  1.465296       1
# 73  3.804222 -1.237853       0
# 81  0.731950  1.791199       1
# 41 -0.382700  0.951713       0
# 43  1.475504  0.893278       1
# 48  0.721604  1.465296       1

# %%
from sklearn.tree import DecisionTreeClassifier

clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
# Fit the model
clf1.fit(df1.iloc[:,0:2], df1.iloc[:, -1])
clf2.fit(df1.iloc[:,0:2], df1.iloc[:, -1])
clf3.fit(df1.iloc[:,0:2], df1.iloc[:, -1])
# Out:
# DecisionTreeClassifier()

# %%
# plot tree
from sklearn.tree import plot_tree
plot_tree(clf1)
plot_tree(clf2)
plot_tree(clf3)
# Out:
# [Text(0.525, 0.95, 'x[1] <= -0.023\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.26666666666666666, 0.85, 'x[0] <= -3.028\ngini = 0.34\nsamples = 46\nvalue = [36, 10]'),
#  Text(0.39583333333333337, 0.8999999999999999, 'True  '),
#  Text(0.23333333333333334, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3, 0.75, 'x[1] <= -1.095\ngini = 0.32\nsamples = 45\nvalue = [36, 9]'),
#  Text(0.23333333333333334, 0.65, 'x[0] <= -1.235\ngini = 0.185\nsamples = 29\nvalue = [26, 3]'),
#  Text(0.2, 0.55, 'x[0] <= -1.241\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.16666666666666666, 0.45, 'x[1] <= -1.804\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.13333333333333333, 0.35, 'x[1] <= -1.981\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.1, 0.25, 'x[1] <= -2.427\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.06666666666666667, 0.15, 'x[0] <= -1.779\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
# ...

# %%
# Let predict the value
clf1.predict(np.array([-1.042498, -0.064323]).reshape(1,2))
# Out:
# C:\Users\ratha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([-1.042498, -0.064323]).reshape(1,2))
# Out:
# C:\Users\ratha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-1.042498, -0.064323]).reshape(1,2))
# Out:
# C:\Users\ratha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
