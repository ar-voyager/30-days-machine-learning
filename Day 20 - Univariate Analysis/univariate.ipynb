# %%
# importing pandas
import pandas as pd
# importing numpy
import numpy as np
# importing seaborn 
import seaborn as sns
# importing matplotlib.pyplot
import matplotlib.pyplot as plt

# others commonly used libraries.___
# import requests
# import time
# import sys
# import io 
# import os
# from bs4 import BeautifulSoup

# %%
# read train.csv dataset
df = pd.read_csv("C:\\Users\\ratha\\MachineA2Z\\Day 19 - EDA(Questioning)\\train.csv")
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# # <b>Categorical Data</b>

# %% [markdown]
# ### <b>CountPlot Chart</b>

# %%
#'Survived' variable
# value_counts()
df['Sex'].value_counts().plot(kind='bar')

# Draw countplot using sns(seaborn)
# sns.countplot(x='Embarked', data=df)
# plt.show()
# Out:
# <Axes: xlabel='Sex'>

# %%
#'Pclass' variable
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# ### <b>Pie Chart<b/>

# %%
# Draw Pie chart of 'Embarked' variable
print(df['Embarked'].value_counts().plot(kind='pie', autopct='%.2f'))
# Out:
# Axes(0.22375,0.11;0.5775x0.77)

# %%
# Draw Pie chart of 'Embarked' variable
print(df['Pclass'].value_counts().plot(kind='pie', autopct='%.2f'))
# Out:
# Axes(0.22375,0.11;0.5775x0.77)

# %% [markdown]
# # <b>Numerical Data</b>

# %%
# Histogram
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
# distplot()
sns.displot(df['Age'])

# %%
# boxplot ('Age')
sns.boxplot(df['Age'], orient='h')
# Out:
# <Axes: xlabel='Age'>

# %%
# boxplot ('Fare')
sns.boxplot(df['Fare'], orient='h')
# Out:
# <Axes: xlabel='Fare'>

# %%
# max() and min() Age
# Get minimum Age
print(df['Age'].min())
# Get maximum Age
print(df['Age'].max())
# Out:
# 0.42
# 80.0

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)
