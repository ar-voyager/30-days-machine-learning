# %%
# importing Pandas
import pandas as pd
# importing Numpy
import numpy as np
# importing library seaborn
import seaborn as sns
# import lib matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %%
# Read train.csv dataset
titanic = pd.read_csv("C:\\Users\\ratha\\MachineA2Z\\Day 19 - EDA(Questioning)\\train.csv")
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
from ydata_profiling import ProfileReport
# Create an Object of ProfileReport
prof = ProfileReport(titanic)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
