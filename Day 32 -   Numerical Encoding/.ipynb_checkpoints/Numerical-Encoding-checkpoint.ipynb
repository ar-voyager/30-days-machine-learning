# %%
# import libraries
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import KBinsDiscretizer
from sklearn.compose import ColumnTransformer

# %%
# pd.read_csv()
df = pd.read_csv('train.csv', usecols=['Age','Fare','Survived'])
# dropna()
df.dropna(inplace=True)
df.shape
# Out:
# (714, 3)

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
X = df.iloc[:,1:3] # inculde all columns except survived
y = df.iloc[:,0]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.20, random_state = 42
)

# %%
# Check for the shape of train and test.
X_train.shape, X_test.shape
# Out:
# ((571, 2), (143, 2))

# %%
# Create Object of 'DecisionTreeClassifier'
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Get the predict values for the X_test
y_pred = clf.predict(X_test)

# Check for the accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.6293706293706294

# %%
# cross_val_score
np.mean(cross_val_score(DecisionTreeClassifier(), X, y, cv=10, scoring = 'accuracy'))
# Out:
# np.float64(0.6275234741784036)

# %%
kbin_age = KBinsDiscretizer(n_bins=19, encode='ordinal', strategy='kmeans')
kbin_fare = KBinsDiscretizer(n_bins=19, encode='ordinal', strategy='kmeans')

# %%
trf = ColumnTransformer([
    ('first', kbin_age, [0]),
    ('second', kbin_fare, [1])
])

# %%
X_train_trf = trf.fit_transform(X_train)
X_test_trf = trf.fit_transform(X_test)

# %%
# transformers data for first column, similar for second.
trf.named_transformers_['first'].bin_edges_
# Out:
# array([array([ 1.        ,  4.33333333,  7.5       , 10.        , 13.63461538,
#               17.82692308, 20.51048951, 23.33484848, 26.65952381, 29.85119048,
#               33.16987179, 36.31868132, 39.10714286, 42.32142857, 45.82142857,
#               49.25      , 52.5       , 55.5       , 59.33333333, 62.        ])],
#       dtype=object)

# %%
output = pd.DataFrame({
    'age':X_train['Age'],
    'age_trf': X_train_trf[:,0],
    'fare': X_train['Fare'],
    'fare_trf': X_train_trf[:,1]
})

# %%
output['age_labels'] = pd.cut(
    x=X_train['Age'],
    bins = trf.named_transformers_['first'].bin_edges_[0].tolist())

output['fare_labels'] = pd.cut(
    x=X_train['Fare'],
    bins = trf.named_transformers_['second'].bin_edges_[0].tolist())

# %%
output.sample(5)
# Out:
#       age  age_trf    fare  fare_trf        age_labels      fare_labels
# 70   32.0      7.0  10.500       1.0   (29.851, 33.17]  (5.689, 10.846]
# 841  16.0      3.0  10.500       1.0  (13.635, 17.827]  (5.689, 10.846]
# 222  51.0     12.0   8.050       1.0     (49.25, 52.5]  (5.689, 10.846]
# 661  40.0      9.0   7.225       1.0  (39.107, 42.321]  (5.689, 10.846]
# 113  20.0      4.0   9.825       1.0   (17.827, 20.51]  (5.689, 10.846]

# %%
# Create Object of 'DecisionTreeclassifier'
clf = DecisionTreeClassifier()
clf.fit(X_train_trf, y_train)

# predict the values
y_pred2 = clf.predict(X_test_trf)

# Get the accuracy score
accuracy_score(y_test, y_pred2)
# Out:
# 0.6013986013986014

# %%
# Define a function Discretizer

def discretizer(bins, strategy):
    kbin_age = KBinsDiscretizer(n_bins=19, encode='ordinal', strategy='kmeans')
    kbin_fare = KBinsDiscretizer(n_bins=19, encode='ordinal', strategy='kmeans')

    trf = ColumnTransformer([
        ('first', kbin_age, [0]),
        ('second', kbin_fare, [1])
    ])

    X_trf = trf.fit_transform(X)
    print(np.mean(cross_val_score(DecisionTreeClassifier(), X, y, cv=10, scoring='accuracy')))

    plt.figure(figsize=(14, 4))
    plt.subplot(121)
    plt.hist(X['Age'])
    plt.title("Before")

    plt.subplot(122)
    plt.hist(X_trf[:, 0], color='red')
    plt.title("After")

    # show graph
    plt.show()

# %%
# Let's call the function
discretizer(10, 'kmeans')
# Out:
# 0.6289123630672926

# %% [markdown]
# ## *Binarization*

# %%
# Out:
#      Survived   Age     Fare
# 0           0  22.0   7.2500
# 1           1  38.0  71.2833
# 2           1  26.0   7.9250
# 3           1  35.0  53.1000
# 4           0  35.0   8.0500
# ..        ...   ...      ...
# 885         0  39.0  29.1250
# 886         0  27.0  13.0000
# 887         1  19.0  30.0000
# 889         1  26.0  30.0000
# 890         0  32.0   7.7500
#
# [714 rows x 3 columns]

# %%
# pd.read_csv()
df = pd.read_csv('train.csv', usecols=['Age','Fare','SibSp', 'Parch','Survived'])
# dropna()
df.dropna(inplace=True)
df.shape
# Out:
# (714, 5)

# %%
df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare
# 0         0  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         1  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         0  35.0      0      0   8.0500

# %%
df['family'] = df['SibSp'] + df['Parch']

# %%
df.head() # Get the top-5 rows 
df.drop(columns=['SibSp', 'Parch'], inplace=True)

# %%
df.head()
# Out:
#    Survived   Age     Fare  family
# 0         0  22.0   7.2500       1
# 1         1  38.0  71.2833       1
# 2         1  26.0   7.9250       0
# 3         1  35.0  53.1000       1
# 4         0  35.0   8.0500       0

# %%
# Dependent and Independent columns
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# %%
X_train.head()
# Out:
#       Age     Fare  family
# 328  31.0  20.5250       2
# 73   26.0  14.4542       1
# 253  30.0  16.1000       1
# 719  33.0   7.7750       0
# 666  25.0  13.0000       0

# %%
# Create Object of DecisionTreeClassifier
clf = DecisionTreeClassifier()

# fit the model
clf.fit(X_train, y_train)

# get y_pred
y_pred1 = clf.predict(X_test)

# accuracy_score
accuracy_score(y_test, y_pred1)
# Out:
# 0.6153846153846154

# %%
# cross_val_score
np.mean(cross_val_score(DecisionTreeClassifier(), X, y, cv= 10, scoring='accuracy'))
# Out:
# np.float64(0.6485328638497652)

# %%
# Apply binarization
from sklearn.preprocessing import Binarizer

# %%
trf = ColumnTransformer([
    ('bin', Binarizer(copy=False), ['family'])
], remainder='passthrough')

# %%
X_train_trf = trf.fit_transform(X_train)
X_test_trf = trf.fit_transform(X_test)

# %%
pd.DataFrame(X_train_trf, columns=['family', 'Age', 'Fare']).head()
# Out:
#    family   Age     Fare
# 0     1.0  31.0  20.5250
# 1     1.0  26.0  14.4542
# 2     1.0  30.0  16.1000
# 3     0.0  33.0   7.7750
# 4     0.0  25.0  13.0000

# %%
# with transformer
# Create Object of DecisionTreeClassifier
clf = DecisionTreeClassifier()

# fit the model
clf.fit(X_train_trf, y_train)

# get y_pred
y_pred2 = clf.predict(X_test_trf)

# accuracy_score
accuracy_score(y_test, y_pred2)
# Out:
# 0.6153846153846154
