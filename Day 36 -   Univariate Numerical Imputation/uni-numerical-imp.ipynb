# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('titanic_toy.csv')
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
# Get the data info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       714 non-null    float64
#  1   Fare      846 non-null    float64
#  2   Family    891 non-null    int64
#  3   Survived  891 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 28.0 KB

# %%
# Check for the null values
df.isnull().mean()
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
# target and independent column
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
# split the data into the test and train.
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# %%
# Check for the shape of the data of train and test
X_train.shape, X_test.shape
# Out:
# ((712, 3), (179, 3))

# %%
# check the null in X_train
X_train.isnull().mean()
# Out:
# Age       0.196629
# Fare      0.050562
# Family    0.000000
# dtype: float64

# %%
# 'Age' Column
mean_age = X_train['Age'].mean()
median_age = X_train['Age'].median()

# 'Fare' Column
mean_fare = X_train['Fare'].mean()
median_fare = X_train['Fare'].median()

# %%
X_train['Age_median'] = X_train['Age'].fillna(median_age)
X_train['Age_mean'] = X_train['Age'].fillna(mean_age)

# 'Fare' Column
X_train['Fare_median'] = X_train['Fare'].fillna(median_fare)
X_train['Fare_mean'] = X_train['Fare'].fillna(mean_fare)

# %%
X_train.sample(5)
# Out:
#       Age      Fare  Family  Age_median  Age_mean  Fare_median   Fare_mean
# 698  49.0       NaN       2        49.0      49.0      14.4000   32.517788
# 799  30.0   24.1500       2        30.0      30.0      24.1500   24.150000
# 372  19.0    8.0500       0        19.0      19.0       8.0500    8.050000
# 761  41.0    7.1250       0        41.0      41.0       7.1250    7.125000
# 258  35.0  512.3292       0        35.0      35.0     512.3292  512.329200

# %%
# check for the variance
print('Original Age variable variance: ', X_train['Age'].var())
print('Age variance after median imputation: ', X_train['Age_median'].var())
print('Age variance after mean imputation: ', X_train['Age_mean'].var())

# check for the variance for Fare column
print('Original Fare variable variance: ', X_train['Fare'].var())
print('Fare variance after median imputation: ', X_train['Fare_median'].var())
print('Fare variance after mean imputation: ', X_train['Fare_mean'].var())
# Out:
# Original Age variable variance:  210.2517072477435
# Age variance after median imputation:  169.20731007048155
# Age variance after mean imputation:  168.85193366872227
# Original Fare variable variance:  2761.0314349486343
# Fare variance after median imputation:  2637.012481677765
# Fare variance after mean imputation:  2621.232374951235

# %%
# Plot the graph
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
X_train['Age'].plot(kind='kde', ax=ax)

# variable imputed with the median
X_train['Age_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
X_train['Age_mean'].plot(kind='kde', ax=ax, color='green')

# Add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
# Plot the graph: Graph change in Fare
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
X_train['Fare'].plot(kind='kde', ax=ax)

# variable imputed with the median
X_train['Fare_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
X_train['Fare_mean'].plot(kind='kde', ax=ax, color='green')

# Add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
# co-variance 
X_train.cov()
# Out:
#                     Age         Fare     Family  Age_median    Age_mean  \
# Age          210.251707    75.481375  -6.993325  210.251707  210.251707
# Fare          75.481375  2761.031435  18.599163   63.938058   60.224654
# Family        -6.993325    18.599163   2.830892   -5.587710   -5.616299
# Age_median   210.251707    63.938058  -5.587710  169.207310  168.851934
# Age_mean     210.251707    60.224654  -5.616299  168.851934  168.851934
# Fare_median   70.082085  2761.031435  17.672035   59.728510   56.282518
# Fare_mean     71.193767  2761.031435  17.657433   60.700688   57.175304
#
#              Fare_median    Fare_mean
# Age            70.082085    71.193767
# Fare         2761.031435  2761.031435
# Family         17.672035    17.657433
# Age_median     59.728510    60.700688
# Age_mean       56.282518    57.175304
# Fare_median  2637.012482  2621.232375
# Fare_mean    2621.232375  2621.232375

# %%
# correlation
X_train.corr()
# Out:
#                   Age      Fare    Family  Age_median  Age_mean  Fare_median  \
# Age          1.000000  0.091482 -0.319651    1.000000  1.000000     0.087232
# Fare         0.091482  1.000000  0.207193    0.093496  0.088151     1.000000
# Family      -0.319651  0.207193  1.000000   -0.255307 -0.256883     0.204536
# Age_median   1.000000  0.093496 -0.255307    1.000000  0.998949     0.089416
# Age_mean     1.000000  0.088151 -0.256883    0.998949  1.000000     0.084346
# Fare_median  0.087232  1.000000  0.204536    0.089416  0.084346     1.000000
# Fare_mean    0.088944  1.000000  0.204981    0.091145  0.085941     0.997003
#
#              Fare_mean
# Age           0.088944
# Fare          1.000000
# Family        0.204981
# Age_median    0.091145
# Age_mean      0.085941
# Fare_median   0.997003
# Fare_mean     1.000000

# %%
X_train[['Age', 'Age_median', 'Age_mean']].boxplot()
# Out:
# <Axes: >

# %%
X_train[['Fare', 'Fare_median', 'Fare_mean']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ## *Through-Sklearn*

# %%
# split the data into the test and train.
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=2
)

# %%
imputer1 = SimpleImputer(strategy='median')
imputer2 = SimpleImputer(strategy='mean')

# %%
trf = ColumnTransformer([
    ('imputer1', imputer1, ['Age']),
    ('imputer2', imputer2, ['Fare'])
], remainder = 'passthrough')

# %%
trf.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imputer1', SimpleImputer(strategy='median'),
#                                  ['Age']),
#                                 ('imputer2', SimpleImputer(), ['Fare'])])

# %%
trf.named_transformers_['imputer1'].statistics_
# Out:
# array([28.75])

# %%
trf.named_transformers_['imputer2'].statistics_
# Out:
# array([32.61759689])

# %%
X_train = trf.transform(X_train)
X_test = trf.transform(X_test)

# %%
X_train
# Out:
# array([[ 40.    ,  27.7208,   0.    ],
#        [  4.    ,  16.7   ,   2.    ],
#        [ 47.    ,   9.    ,   0.    ],
#        ...,
#        [ 71.    ,  49.5042,   0.    ],
#        [ 28.75  , 221.7792,   0.    ],
#        [ 28.75  ,  25.925 ,   0.    ]])

# %% [markdown]
# ## *Arbitrary Value Imputation*

# %%
# split the data into the test and train.
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=2
)

# %%
X_train['Age_99'] = X_train['Age'].fillna(99)
X_train['Age_minus1'] = X_train['Age'].fillna(-1)

X_train['Fare_999'] = X_train['Fare'].fillna(999)
X_train['Fare_minus1'] = X_train['Fare'].fillna(-1)

# %%
print('Original Age variable variance: ', X_train['Age'].var())
print('Age Variance after 99 wala imputation: ', X_train['Age_99'].var())
print('Age Variance after -1 wala imputation: ', X_train['Age_minus1'].var())

print('Original Fare variable variance: ', X_train['Fare'].var())
print('Fare Variance after 999 wala imputation: ', X_train['Fare_999'].var())
print('Fare Variance after -1 wala imputation: ', X_train['Fare_minus1'].var())
# Out:
# Original Age variable variance:  204.34951339046142
# Age Variance after 99 wala imputation:  951.7275570187188
# Age Variance after -1 wala imputation:  318.0896202624488
# Original Fare variable variance:  2448.1979137063163
# Fare Variance after 999 wala imputation:  47219.202652176304
# Fare Variance after -1 wala imputation:  2378.5676784883494

# %% [markdown]
# ### *Visualizing the Distribution*

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# Original Age variable distribution
X_train['Age'].plot(kind='kde', ax=ax)

# Age after 99 imputation
X_train['Age_99'].plot(kind='kde', ax=ax, color='red')

# Age after -1 imputation
X_train['Age_minus1'].plot(kind='kde', ax=ax, color='green')

# Add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# Original Fare variable distribution
X_train['Fare'].plot(kind='kde', ax=ax)

# Fare after 999 imputation
X_train['Fare_999'].plot(kind='kde', ax=ax, color='red')

# Fare after -1 imputation
X_train['Fare_minus1'].plot(kind='kde', ax=ax, color='green')

# Add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
plt.show()

# %% [markdown]
# ### **

# %%
# cov
X_train.cov()
# Out:
#                     Age         Fare     Family      Age_99  Age_minus1  \
# Age          204.349513    70.719262  -6.498901  204.349513  204.349513
# Fare          70.719262  2448.197914  17.258917 -101.671097  125.558364
# Family        -6.498901    17.258917   2.735252   -7.387287   -4.149246
# Age_99       204.349513  -101.671097  -7.387287  951.727557 -189.535540
# Age_minus1   204.349513   125.558364  -4.149246 -189.535540  318.089620
# Fare_999     162.793430  2448.197914  11.528625 -159.931663  257.379887
# Fare_minus1   63.321188  2448.197914  16.553989  -94.317400  114.394141
#
#                  Fare_999  Fare_minus1
# Age            162.793430    63.321188
# Fare          2448.197914  2448.197914
# Family          11.528625    16.553989
# Age_99        -159.931663   -94.317400
# Age_minus1     257.379887   114.394141
# Fare_999     47219.202652   762.474982
# Fare_minus1    762.474982  2378.567678

# %%
# corr
X_train.corr()
# Out:
#                   Age      Fare    Family    Age_99  Age_minus1  Fare_999  \
# Age          1.000000  0.092644 -0.299113  1.000000    1.000000  0.051179
# Fare         0.092644  1.000000  0.208268 -0.066273    0.142022  1.000000
# Family      -0.299113  0.208268  1.000000 -0.144787   -0.140668  0.032079
# Age_99       1.000000 -0.066273 -0.144787  1.000000   -0.344476 -0.023857
# Age_minus1   1.000000  0.142022 -0.140668 -0.344476    1.000000  0.066411
# Fare_999     0.051179  1.000000  0.032079 -0.023857    0.066411  1.000000
# Fare_minus1  0.084585  1.000000  0.205233 -0.062687    0.131514  0.071946
#
#              Fare_minus1
# Age             0.084585
# Fare            1.000000
# Family          0.205233
# Age_99         -0.062687
# Age_minus1      0.131514
# Fare_999        0.071946
# Fare_minus1     1.000000

# %%
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imputer1',
#                                  SimpleImputer(fill_value=99,
#                                                strategy='constant'),
#                                  ['Age']),
#                                 ('imputer2',
#                                  SimpleImputer(fill_value=999,
#                                                strategy='constant'),
#                                  ['Fare'])])

# %% [markdown]
# ### *Arbitrary Value Imputation with sklearn*

# %%
imputer1 = SimpleImputer(strategy='constant', fill_value=99)
imputer2 = SimpleImputer(strategy='constant', fill_value=999)

trf1 = ColumnTransformer([
    ('imputer1', imputer1, ['Age']),
    ('imputer2', imputer2, ['Fare'])
], remainder='passthrough')

trf1.fit(X_train)
X_train = trf1.transform(X_train)
X_test = trf1.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_indexing.py:446, in _get_column_indices(X, key)
#     445 try:
# --> 446     all_columns = X.columns
#     447 except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 9
#       2 imputer2 = SimpleImputer(strategy='constant', fill_value=999)
#       4 trf1 = ColumnTransformer([
#       5     ('imputer1', imputer1, ['Age']),
#       6     ('imputer2', imputer2, ['Fare'])
#       7 ], remainder='passthrough')
# ----> 9 trf1.fit(X_train)
#      10 X_train = trf1.transform(X_train)
#      11 X_test = trf1.transform(X_test)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:938, in ColumnTransformer.fit(self, X, y, **params)
#     935 _raise_for_params(params, self, "fit")
#     936 # we use fit_transform to make sure to set sparse_output_ (for which we
#     937 # need the transformed data) to have consistent output type in predict
# --> 938 self.fit_transform(X, y=y, **params)
#     939 return self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:991, in ColumnTransformer.fit_transform(self, X, y, **params)
#     988 self._validate_transformers()
#     989 n_samples = _num_samples(X)
# --> 991 self._validate_column_callables(X)
#     992 self._validate_remainder(X)
#     994 if _routing_enabled():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:545, in ColumnTransformer._validate_column_callables(self, X)
#     543         columns = columns(X)
#     544     all_columns.append(columns)
# --> 545     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     547 self._columns = all_columns
#     548 self._transformer_to_input_indices = transformer_to_input_indices
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_indexing.py:448, in _get_column_indices(X, key)
#     446     all_columns = X.columns
#     447 except AttributeError:
# --> 448     raise ValueError(
#     449         "Specifying the columns using strings is only supported for dataframes."
#     450     )
#     451 if isinstance(key, str):
#     452     columns = [key]
#
# ValueError: Specifying the columns using strings is only supported for dataframes.
