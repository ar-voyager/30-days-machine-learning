# %%
# pandas and numpy library
import pandas as pd
import numpy as np
# requests library, Extracting data through API
import requests
# BeautifulSoup for extracting Data using WebScraping
from bs4 import BeautifulSoup

# %%
URL = 'https://www.ambitionbox.com/list-of-companies?page=1'
headers = {"User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36'}
webpage = requests.get(URL, headers=headers).text

# %%
# Creating object of BeautifulSoup Class
soup = BeautifulSoup(webpage, 'lxml')
soup.find_all('h2')[0]
# Out:
# <h2 class="companyListing__title">
# 							Companies in India
# 						</h2>

# %%
# Extracting Company name from Header2 tag
for i in range(1, len(soup.find_all('h2'))):
    print(soup.find_all('h2')[i].text.strip())
    i+=1
# Out:
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# ICICI Bank
# HCLTech
# Tech Mahindra
# Genpact
# Teleperformance
# Axis Bank
# Concentrix Corporation
# Jio
# Amazon
# iEnergizer
# Reliance Retail
# IBM
# LTIMindtree

# %%
# Extracting companies rating through website AmbitionBox
for rating in soup.find_all('div', class_="rating_text rating_text--md"):
    print(rating.text.strip())
# Out:
# 3.5
# 3.7
# 3.7
# 3.7
# 3.7
# 3.8
# 3.5
# 4.0
# 3.4
# 3.4
# 3.7
# 3.9
# 3.7
# 3.6
# 4.3
# 4.0
# 4.7
# 3.9
# 3.9
# 3.7

# %%
# Extracting company review 
for review in soup.find_all('span', class_="companyCardWrapper__companyRatingCount"):
    print(review.text.strip())
# Out:
# (1L)
# (66.8k)
# (59.9k)
# (56.9k)
# (48.7k)
# (46.5k)
# (44.8k)
# (42.6k)
# (41.8k)
# (40k)
# (38.1k)
# (34.2k)
# (30k)
# (29.7k)
# (28.8k)
# (28.8k)
# (26.5k)
# (25.3k)
# (24.3k)
# (23.8k)

# %%
# Extracting company Description
for review in soup.find_all('span', class_="companyCardWrapper__interLinking"):
    print(review.text.strip())
# Out:
# IT Services & Consulting | Bangalore / Bengaluru +421 other locations
# IT Services & Consulting | Bangalore / Bengaluru +235 other locations
# IT Services & Consulting | Bangalore / Bengaluru +363 other locations
# IT Services & Consulting | Hyderabad / Secunderabad +220 other locations
# IT Services & Consulting | Bangalore / Bengaluru +177 other locations
# Banking | Mumbai +1745 other locations
# IT Services & Consulting | Bangalore / Bengaluru +235 other locations
# Banking | Mumbai +1399 other locations
# IT Services & Consulting | Chennai +220 other locations
# IT Services & Consulting | Hyderabad / Secunderabad +325 other locations
# IT Services & Consulting | Hyderabad / Secunderabad +166 other locations
# BPO | Mumbai +244 other locations
# Banking | Mumbai +1464 other locations
# BPO | Bangalore / Bengaluru +169 other locations
# Telecom | Mumbai +1749 other locations
# Internet | Bangalore / Bengaluru +504 other locations
# BPO | Noida +47 other locations
# Retail | Mumbai +1116 other locations
# IT Services & Consulting | Bangalore / Bengaluru +157 other locations
# IT Services & Consulting | Bangalore / Bengaluru +137 other locations

# %%
# Extracting company for which Rated High
company = soup.find_all('div', class_='companyCardWrapper')
len_cmpy = len(company)

# %%
company_name, rating, review, highly_rated, Critically_rated = [], [], [], [], []
for num in company:
    company_name.append(num.find('h2').text.strip())
    rating.append(num.find('div', class_="rating_text rating_text--md").text.strip())
    review.append(num.find('span', class_="companyCardWrapper__companyRatingCount").text.strip())
    # highly_rated.append(num.find_all('span', class_="companyCardWrapper__ratingValues")[0].text.strip())
    # highly_rated.append(num.find_all('span', class_="companyCardWrapper__ratingValues")[1].text.strip())

# %%
# Converted extracted of top-list-of-companies from AmbitionBox(Website).
# np.array(), a function of numpy python libraray.
# Ectracted lists: company_name, rating, review, highly_rated, Critically_rated
np.array([company_name, rating, review, highly_rated, Critically_rated])
# Out:
# array([['TCS', 'Accenture', 'Wipro', 'Cognizant', 'Capgemini',
#         'HDFC Bank', 'Infosys', 'ICICI Bank', 'HCLTech', 'Tech Mahindra',
#         'Genpact', 'Teleperformance', 'Axis Bank',
#         'Concentrix Corporation', 'Jio', 'Amazon', 'iEnergizer',
#         'Reliance Retail', 'IBM', 'LTIMindtree'],
#        ['3.5', '3.7', '3.7', '3.7', '3.7', '3.8', '3.5', '4.0', '3.4',
#         '3.4', '3.7', '3.9', '3.7', '3.6', '4.3', '4.0', '4.7', '3.9',
#         '3.9', '3.7'],
#        ['(1L)', '(66.8k)', '(59.9k)', '(56.9k)', '(48.7k)', '(46.5k)',
#         '(44.8k)', '(42.6k)', '(41.8k)', '(40k)', '(38.1k)', '(34.2k)',
#         '(30k)', '(29.7k)', '(28.8k)', '(28.8k)', '(26.5k)', '(25.3k)',
#         '(24.3k)', '(23.8k)'],
#        ['Job Security', 'NA', 'Job Security', 'NA',
#         'Work Life Balance, Job Security',
#         'Job Security, Skill Development / Learning', 'Job Security',
#         'Job Security, Skill Development / Learning, Company Culture',
#         'NA', 'NA', 'Job Security',
#         'Work Life Balance, Job Security, Skill Development / Learning',
#         'NA', 'Job Security',
#         'Job Security, Company Culture, Work Life Balance',
#         'Company Culture, Work Life Balance, Salary & Benefits',
#         'Salary & Benefits, Company Culture, Work Life Balance',
#         'Skill Development / Learning, Job Security',
#         'Work Life Balance, Company Culture, Job Security', 'NA'],
#        ['Promotions / Appraisal, Salary & Benefits, Work Satisfaction',
#         'Promotions / Appraisal, Salary & Benefits, Work Satisfaction',
#         'Promotions / Appraisal, Salary & Benefits, Work Satisfaction',
#         'Promotions / Appraisal, Salary & Benefits, Work Satisfaction',
#         'Promotions / Appraisal, Salary & Benefits, Work Satisfaction',
#         'Promotions / Appraisal',
#         'Promotions / Appraisal, Salary & Benefits, Work Satisfaction',
#         'NA',
#         'Promotions / Appraisal, Salary & Benefits, Work Satisfaction',
#         'Promotions / Appraisal, Salary & Benefits, Work Satisfaction',
#         'Promotions / Appraisal, Salary & Benefits', 'NA',
#         'Promotions / Appraisal, Company Culture, Work Satisfaction',
#         'Promotions / Appraisal, Salary & Benefits, Work Satisfaction',
#         'NA', 'Promotions / Appraisal', 'NA', 'Promotions / Appraisal',
#         'Promotions / Appraisal',
#         'Promotions / Appraisal, Salary & Benefits']], dtype='<U61')

# %%
# Highly rated Companies for the reason they are known.
for i in range(len_cmpy):
    if company[i].find_all('div', class_="companyCardWrapper__ratingHeader")[0].text ==' Highly Rated For':
        highly_rated.append(company[i].find_all('span', class_="companyCardWrapper__ratingValues")[0].text)
    else:
        highly_rated.append("NA")

# %%
# Companies Data because of that they are critised
for i in range(len_cmpy):
    if len(company[i].find_all('div', class_="companyCardWrapper__ratingHeader")) == 1:
        if company[i].find_all('div', class_="companyCardWrapper__ratingHeader")[0].text ==' Critically Rated For': 
            Critically_rated.append(company[i].find_all('span', class_="companyCardWrapper__ratingValues")[0].text)
        else:
            Critically_rated.append("NA")
    else:
        if company[i].find_all('div', class_="companyCardWrapper__ratingHeader")[1].text ==' Critically Rated For': 
            Critically_rated.append(company[i].find_all('span', class_="companyCardWrapper__ratingValues")[1].text)
        else:
            Critically_rated.append("NA")

# %%
# Creating a DataFrame of Extracted Columns
# and Do the transpose of the DataFrame
df = pd.DataFrame([company_name, rating, review, highly_rated, Critically_rated]).transpose()

# %%
# DataFrame (df) calling it's function called (head(10) # No.of rows).
# getted subset of Columns.
df.head(10)[[0,1,2]]
# Out:
#                0    1        2
# 0            TCS  3.5     (1L)
# 1      Accenture  3.7  (66.8k)
# 2          Wipro  3.7  (59.9k)
# 3      Cognizant  3.7  (56.9k)
# 4      Capgemini  3.7  (48.7k)
# 5      HDFC Bank  3.8  (46.5k)
# 6        Infosys  3.5  (44.8k)
# 7     ICICI Bank  4.0  (42.6k)
# 8        HCLTech  3.4  (41.8k)
# 9  Tech Mahindra  3.4    (40k)
